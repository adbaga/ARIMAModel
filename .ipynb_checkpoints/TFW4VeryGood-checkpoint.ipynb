# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from scipy import stats as st
import seaborn as sns; sns.set(style="ticks", color_codes=True)
from datetime import datetime

from sklearn.preprocessing import LabelEncoder
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm

# %%
data = pd.read_excel('TWDataset2.xlsx')
data1 = data.iloc[:,0:8:7]


dfA = data.loc[(data['payment_method'] == 'A' )]
dfB = data.loc[data['payment_method'] == 'B']
dfC = data.loc[data['payment_method'] == 'C']
dfAB = data.loc[(data['payment_method'] == 'A' ) | (data['payment_method'] == 'B') ]

dataA = data.iloc[:,0:7:6]
dataB = data.iloc[:,0:7:6]
dataC = data.iloc[:,0:7:6]
dataAB = data.iloc[:,0:7:6]

dfAGroup = dfA.groupby([dfA['transfer_created_by_customer_time'].dt.date], as_index=True,).mean()
dfBGroup = dfB.groupby([dfB['transfer_created_by_customer_time'].dt.date], as_index=True,).mean()
dfCGroup = dfC.groupby([dfC['transfer_created_by_customer_time'].dt.date], as_index=True,).mean()

dfABGroup = dfAB.groupby([dfAB['transfer_created_by_customer_time'].dt.date], as_index=True,).mean()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA

plot_acf(dfAGroup)
plot_pacf(dfAGroup)

# %%
# fit model
model = ARIMA(dfCGroup, order=(3,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# /Users/kalevkim/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/kalevkim/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.deliv_dur_min   No. Observations:                   73
# Model:                 ARIMA(3, 1, 1)   Log Likelihood                -735.663
# Method:                       css-mle   S.D. of innovations           5605.779
# Date:                Sat, 21 Mar 2020   AIC                           1483.326
# Time:                        13:05:08   BIC                           1497.069
# Sample:                             1   HQIC                          1488.803
#
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.1530     38.074      0.004      0.997     -74.472      74.778
# ar.L1.D.deliv_dur_min     0.0364      0.116      0.315      0.754      -0.190       0.263
# ar.L2.D.deliv_dur_min    -0.0208      0.115     -0.180      0.857      -0.246       0.205
# ar.L3.D.deliv_dur_min     0.2061      0.115      1.795      0.077      -0.019       0.431
# ma.L1.D.deliv_dur_min    -1.0000      0.037    -26.890      0.000      -1.073      -0.927
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7955           -1.4951j            1.6935           -0.3278
# AR.2           -0.7955           +1.4951j            1.6935            0.3278
# AR.3            1.6917           -0.0000j            1.6917           -0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d9e224fd2433> in <module>
#       4 print(model_fit.summary())
#       5 # plot residual errors
# ----> 6 residuals = DataFrame(model_fit.resid)
#       7 residuals.plot()
#       8 pyplot.show()
#
# NameError: name 'DataFrame' is not defined

# %%
X = dfAGroup.values
size = int(len(X) * 0.53)
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3,1,1))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print(' Test MSE: %.3f' % error)

# plot
plt.figure(figsize = (30,10))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
from sklearn.model_selection import learning_curve
train_sizes = learning_curve(RandomForestClassifier()


# Create means and standard deviations of training set scores
train_mean = np.mean(train, axis=1)
train_std = np.std(train, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test, axis=1)
test_std = np.std(test, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ffa9a7f6bebe> in <module>
#      12
#      13 # Draw lines
# ---> 14 plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
#      15 plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")
#      16
#
# NameError: name 'train_sizes' is not defined

# %%
dfAGroup[180:210]

#4299 is 18/07
#6933 is 23/12
# Out:
#                                    deliv_dur_min
# transfer_created_by_customer_time
# 2015-07-03                           6573.446667
# 2015-07-04                           8796.608333
# 2015-07-05                           3052.700000
# 2015-07-06                           3560.085897
# 2015-07-07                           5158.625000
# 2015-07-08                           3397.175000
# 2015-07-09                           4894.620833
# 2015-07-10                           5399.063889
# 2015-07-11                           4127.116667
# 2015-07-12                           3135.295833
# 2015-07-13                           3698.821429
# 2015-07-14                           5234.841667
# 2015-07-15                           6612.904167
# 2015-07-16                           6217.096667
# 2015-07-17                           5107.161111
# 2015-07-18                           4299.922222
# 2015-07-19                           3266.762500
# 2015-07-20                           3651.981481
# 2015-07-21                           3748.548148
# 2015-07-22                           5349.823810
# 2015-07-23                           5922.910417
# 2015-07-24                           5236.716667
# 2015-07-25                           4708.152083
# 2015-07-26                           2886.472917
# 2015-07-27                           3273.397222
# 2015-07-28                           2726.096667
# 2015-07-29                           5005.992593
# 2015-07-30                           6259.375000
# 2015-07-31                           5121.291667
# 2015-08-01                           4206.600000

# %%
X = dfBGroup.values
size = int(len(X) * 0.6)
size= round(size)
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(2,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print(' Test MSE: %.3f' % error)

# plot
plt.figure(figsize = (30,10))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=507.961988, expected=2402.372222
# predicted=1060.714721, expected=99.466667
# predicted=1208.507520, expected=61.250000
# predicted=914.830666, expected=126.208333
# predicted=94.808017, expected=729.533333
# predicted=300.248669, expected=416.550000
# predicted=466.894935, expected=50.550000
# predicted=418.821483, expected=1565.138889
# predicted=635.594158, expected=53.083333
# predicted=675.300750, expected=41.308333
# predicted=577.517895, expected=27.083333
# predicted=40.706330, expected=3491.500000
# predicted=1093.590922, expected=772.516667
# predicted=1659.227202, expected=39.800000
# predicted=1636.039378, expected=42.533333
# predicted=276.417774, expected=160.412500
# predicted=83.254364, expected=55.204167
# predicted=89.268595, expected=453.983333
# predicted=230.275434, expected=72.900000
# predicted=205.571337, expected=117.894444
# predicted=212.081553, expected=54.450000
# predicted=83.381685, expected=402.808333
# predicted=197.514246, expected=1296.466667
# predicted=621.360063, expected=63.116667
# predicted=616.858081, expected=43.916667
# predicted=459.799481, expected=78.966667
# predicted=62.355311, expected=43.600000
# predicted=56.049336, expected=47.783333
#  Test MSE: 1031123.603

# %%
error = mean_squared_error(test, predictions)
print(' Test MSE: %.3f' % error)
# Out:
#  Test MSE: 1031123.603

# %%
dfBGroup

#402.808333 is 23/12
# Out:
#                                    deliv_dur_min
# transfer_created_by_customer_time
# 2015-09-21                             46.391667
# 2015-09-23                             41.750000
# 2015-09-27                             56.133333
# 2015-09-28                             81.000000
# 2015-10-03                             47.950000
# 2015-10-05                            105.733333
# 2015-10-09                             27.283333
# 2015-10-10                            421.416667
# 2015-10-11                             74.258333
# 2015-10-12                             57.144444
# 2015-10-13                             56.750000
# 2015-10-16                             35.366667
# 2015-10-17                            733.166667
# 2015-10-18                            182.600000
# 2015-10-19                             38.200000
# 2015-10-20                             42.000000
# 2015-10-22                            149.388889
# 2015-10-24                            127.783333
# 2015-10-26                             92.161111
# 2015-10-27                            672.941667
# 2015-10-28                             50.666667
# 2015-10-29                            124.933333
# 2015-10-31                            110.750000
# 2015-11-01                            926.200000
# 2015-11-02                            630.833333
# 2015-11-03                            529.950000
# 2015-11-04                             59.766667
# 2015-11-07                           1217.366667
# 2015-11-08                            579.333333
# 2015-11-09                             43.625000
# 2015-11-10                             33.200000
# 2015-11-11                            576.750000
# 2015-11-14                             77.966667
# 2015-11-15                            403.183333
# 2015-11-16                           5447.733333
# 2015-11-17                             45.650000
# 2015-11-18                            907.175000
# 2015-11-19                             65.908333
# 2015-11-22                            588.633333
# 2015-11-24                            482.694444
# 2015-11-25                            385.241667
# 2015-11-26                           2402.372222
# 2015-11-29                             99.466667
# 2015-11-30                             61.250000
# 2015-12-01                            126.208333
# 2015-12-02                            729.533333
# 2015-12-03                            416.550000
# 2015-12-06                             50.550000
# 2015-12-07                           1565.138889
# 2015-12-08                             53.083333
# 2015-12-09                             41.308333
# 2015-12-10                             27.083333
# 2015-12-11                           3491.500000
# 2015-12-14                            772.516667
# 2015-12-15                             39.800000
# 2015-12-16                             42.533333
# 2015-12-17                            160.412500
# 2015-12-18                             55.204167
# 2015-12-19                            453.983333
# 2015-12-20                             72.900000
# 2015-12-21                            117.894444
# 2015-12-22                             54.450000
# 2015-12-23                            402.808333
# 2015-12-24                           1296.466667
# 2015-12-27                             63.116667
# 2015-12-28                             43.916667
# 2015-12-29                             78.966667
# 2015-12-30                             43.600000
# 2015-12-31                             47.783333

# %%
X = dfCGroup.values
size = int(len(X) * 0.6)
size= round(size)
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(2,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print(' Test MSE: %.3f' % error)

# plot
plt.figure(figsize = (30,10))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=8205.087335, expected=6946.183333
# predicted=6951.029145, expected=11614.983333
# predicted=8812.223707, expected=3380.066667
# predicted=7331.037356, expected=2888.316667
# predicted=7493.257223, expected=780.566667
# predicted=2581.396272, expected=3586.950000
# predicted=2737.286667, expected=5737.416667
# predicted=3085.689244, expected=8783.750000
# predicted=5957.933166, expected=2822.516667
# predicted=5772.283320, expected=1753.916667
# predicted=5460.486150, expected=2888.500000
# predicted=2711.031912, expected=3862.866667
# predicted=2787.224381, expected=69.366667
# predicted=2304.695244, expected=2785.083333
# predicted=2774.237181, expected=2839.050000
# predicted=1610.993889, expected=3776.366667
# predicted=3225.442110, expected=1027.350000
# predicted=2572.752436, expected=2728.233333
# predicted=2931.079811, expected=4721.904167
# predicted=2659.579082, expected=4508.770833
# predicted=3867.109634, expected=4477.795833
# predicted=4749.756156, expected=702.150000
# predicted=3416.546527, expected=2023.375000
# predicted=2948.220821, expected=2314.113333
# predicted=1555.492962, expected=4329.916667
# predicted=2909.958443, expected=993.133333
# predicted=2425.233382, expected=4082.016667
# predicted=3611.112834, expected=914.050000
# predicted=1723.136121, expected=5601.883333
# predicted=3938.322892, expected=2347.900000
#  Test MSE: 9196673.588

# %%
error = mean_squared_error(test, predictions)
print(' Test MSE: %.3f' % error)
# Out:
#  Test MSE: 9196673.588

# %%
dfCGroup
#2888.316667 is 10/08
#3380.066667 is 06/07
# Out:
#                                    deliv_dur_min
